# %% [markdown]
# <a href="https://colab.research.google.com/github/AnuragTiwari-hub/AIML/blob/main/AIML_15_(Z_score).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
import pandas as pd

# Sample data (can be a NumPy array or a Pandas DataFrame)
data = np.array([[1, 2], [3, 4], [5, 6], [7, 8]])
# or data = pd.DataFrame({'col1': [1, 3, 5, 7], 'col2': [2, 4, 6, 8]})

# Initialize the scaler
scaler = StandardScaler()

# Fit and transform the data
standardized_data = scaler.fit_transform(data)

print("Standardized Data (Z-score Normalization):")
print(standardized_data)
# Out:
# Standardized Data (Z-score Normalization):
# [[-1.34164079 -1.34164079]
#  [-0.4472136  -0.4472136 ]
#  [ 0.4472136   0.4472136 ]
#  [ 1.34164079  1.34164079]]
